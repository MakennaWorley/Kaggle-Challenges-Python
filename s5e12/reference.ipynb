# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/playground-series-s5e12/sample_submission.csv
# /kaggle/input/playground-series-s5e12/train.csv
# /kaggle/input/playground-series-s5e12/test.csv

# %%
import pandas as pd
import numpy as np
from catboost import CatBoostClassifier, Pool
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score

# %%
train = pd.read_csv("/kaggle/input/playground-series-s5e12/train.csv")
test  = pd.read_csv("/kaggle/input/playground-series-s5e12/test.csv")

# TARGET = "diagnosed_diabetes"
test_id = test["id"]

# %%
TARGET = "diagnosed_diabetes"
test_ids = test["id"]
X = train.drop(columns=[TARGET])
y = train[TARGET]
test_X = test.copy()

cat_cols = X.select_dtypes(include=["object"]).columns.tolist()
cat_features = [X.columns.get_loc(col) for col in cat_cols]

# %%
cat_params = {
    "loss_function": "Logloss",
    "eval_metric": "AUC",
    "iterations": 10000,
    "learning_rate": 0.025,
    "depth": 6,
    "l2_leaf_reg": 10,
    "random_strength": 1.0,
    "auto_class_weights": "Balanced",
    "bootstrap_type": "Bayesian",
    "bagging_temperature": 1.2,
    "min_data_in_leaf": 50,
    "od_type": "Iter",
    "od_wait": 200,
    "verbose": 0,
    "task_type": "GPU"
}

# %%
SEEDS = [49, 101, 64, 13, 491, 27, 17, 121, 997, 19, 9409, 8, 11, 16, 529, 23, 14641, 4, 99991, 81]
N_SPLITS = 7

train_oof = np.zeros(len(X))
test_preds = np.zeros(len(test))

for seed in SEEDS:
    print(f"\nTraining seed: {seed}")
    
    skf = StratifiedKFold(
        n_splits=N_SPLITS,
        shuffle=True,
        random_state=seed
    )

    seed_test_preds = np.zeros(len(test))
    fold_scores = []

    for fold, (tr_idx, val_idx) in enumerate(skf.split(X, y)):
        X_tr, X_val = X.iloc[tr_idx], X.iloc[val_idx]
        y_tr, y_val = y.iloc[tr_idx], y.iloc[val_idx]

        model = CatBoostClassifier(
            **cat_params,
            random_seed=seed
        )

        model.fit(
            X_tr, y_tr,
            eval_set=(X_val, y_val),
            cat_features=cat_cols,
            use_best_model=True,
            early_stopping_rounds=100 
        )

        val_pred = model.predict_proba(X_val)[:, 1]

        train_oof[val_idx] += val_pred
        
        auc = roc_auc_score(y_val, val_pred)
        fold_scores.append(auc)

        seed_test_preds += model.predict_proba(test)[:, 1] / N_SPLITS

    print(f"Seed {seed} mean AUC:", np.mean(fold_scores))
    test_preds += seed_test_preds / len(SEEDS)
# Out:
# Training seed: 49
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 49 mean AUC: 0.7255924799967273
#
# Training seed: 101
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 101 mean AUC: 0.7255466316116664
#
# Training seed: 64
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 64 mean AUC: 0.7254655882983604
#
# Training seed: 13
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 13 mean AUC: 0.7255553749151324
#
# Training seed: 491
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 491 mean AUC: 0.7256018167040136
#
# Training seed: 27
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 27 mean AUC: 0.7256133012551282
#
# Training seed: 17
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 17 mean AUC: 0.7255270663825965
#
# Training seed: 121
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 121 mean AUC: 0.725558510213047
#
# Training seed: 997
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 997 mean AUC: 0.725550409598892
#
# Training seed: 19
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 19 mean AUC: 0.7254756372210963
#
# Training seed: 9409
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 9409 mean AUC: 0.7256218357377661
#
# Training seed: 8
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 8 mean AUC: 0.7255837245975425
#
# Training seed: 11
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 11 mean AUC: 0.7255213651209697
#
# Training seed: 16
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 16 mean AUC: 0.7255958612253256
#
# Training seed: 529
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 529 mean AUC: 0.7255593884589907
#
# Training seed: 23
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 23 mean AUC: 0.7256622865259302
#
# Training seed: 14641
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 14641 mean AUC: 0.7254804082629158
#
# Training seed: 4
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 4 mean AUC: 0.725456085203973
#
# Training seed: 99991
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 99991 mean AUC: 0.7255130997955657
#
# Training seed: 81
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Seed 81 mean AUC: 0.7254455789248367

# %%
submission = pd.DataFrame({
    "id": test_id,
    TARGET: test_preds
})

submission.to_csv("catboost_strategy4_seed_avg.csv", index=False)
submission.head()
# Out:
#        id  diagnosed_diabetes
# 0  700000            0.394793
# 1  700001            0.584406
# 2  700002            0.659651
# 3  700003            0.310168
# 4  700004            0.860946
